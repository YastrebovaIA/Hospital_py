# %%
import openpyxl

# %%
wb=openpyxl.reader.excel.load_workbook(filename="D:\\task_python.xlsx")

# %%
import pandas as pd

# %%
file = 'D:\\task_python.xlsx'

# %%
xl = pd.ExcelFile(file)

# %%
print(xl.sheet_names)
# Out:
# ['Получить свод', 'Есть в Отчете 2, нет в Отчете 1', 'Есть в отчете 1, нет в Отчете 2', 'Отчет 1', 'Отчет 2']

# %%
df1 = xl.parse('Отчет 1')
df2 = xl.parse('Отчет 2')
df2
# Out:
#                                        Юридическое лицо     Фамилия  \
# 0                                           АО ГК МЕДСИ      ЖУКОВА
# 1            ГАУЗ МО Воскресенская районная больница №2  Афанасьева
# 2            ГАУЗ МО Воскресенская районная больница №2  БЕЛЬДЕНКОВ
# 3            ГАУЗ МО Воскресенская районная больница №2     ВАВИЛОВ
# 4            ГАУЗ МО Воскресенская районная больница №2    ВАСИЛЬЕВ
# ...                                                 ...         ...
# 6736  ФГБУ "ФЕДЕРАЛЬНЫЙ КЛИНИЧЕСКИЙ ЦЕНТР ВЫСОКИХ МЕ...    ЩЕРБАКОВ
# 6737  ФГБУ "ФЕДЕРАЛЬНЫЙ КЛИНИЧЕСКИЙ ЦЕНТР ВЫСОКИХ МЕ...    ЯГОФАРОВ
# 6738  ФГБУ "ФЕДЕРАЛЬНЫЙ КЛИНИЧЕСКИЙ ЦЕНТР ВЫСОКИХ МЕ...   ЯГОФАРОВА
# 6739  ФГБУ "ФЕДЕРАЛЬНЫЙ КЛИНИЧЕСКИЙ ЦЕНТР ВЫСОКИХ МЕ...    КОРНЕЕВА
# 6740                         ФГБУЗ МСЧ №152 ФМБА РОССИИ     АГАРКОВ
#
#              Имя        Отчество
# 0          МАРИЯ    ВЛАДИМИРОВНА
# 1         Оксана      Дмитриевна
# 2     КОНСТАНТИН       СЕРГЕЕВИЧ
# ...

# %%
dict = {'ГАУЗ МО Воскресенская районная больница №2':'ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2',
                   'ГАУЗ МО Клинический центр восстановительной медицины и реабилитации':'ГАУЗ МО КЦВМиР',
                   'ГАУЗ МО Химкинская областная больница':'ГАУЗ МО ХИМКИНСКАЯ ОБ',
                   'ГАУЗ МО Центральная городская больница имени М.В. Гольца':'ГАУЗ МО ЦГБ им. М.В. Гольца',
                   'ГБУЗ МО Каширская центральная районная больница':'ГБУЗ МО КАШИРСКАЯ ЦРБ',
                   'ГБУЗ МОСКОВСКОЙ ОБЛАСТИ  "ПОДОЛЬСКАЯ ГОРОДСКАЯ КЛИНИЧЕСКАЯ БОЛЬНИЦА"':'ГБУЗ МО ЧЕХОВСКАЯ ОБ',
                   'ГБУЗ МОСКОВСКОЙ ОБЛАСТИ  "ПОДОЛЬСКАЯ ГОРОДСКАЯ КЛИНИЧЕСКАЯ БОЛЬНИЦА"':'ГБУЗ МО ПОДОЛЬСКАЯ ГКБ',
                   'ГБУЗ МО Балашихинская областная больница':'ГБУЗ МО БАЛАШИХИНСКАЯ ОБ',
                   'ГБУЗ МО Волоколамская центральная районная больница':'ГБУЗ МО ВОЛОКОЛАМСКАЯ ЦРБ',
                   'ГБУЗ МО Воскресенская первая районная больница':'ГБУЗ МО ВОСКРЕСЕНСКАЯ ПРБ',
                   'ФГБУ "ФЕДЕРАЛЬНЫЙ КЛИНИЧЕСКИЙ ЦЕНТР ВЫСОКИХ МЕДИЦИНСКИХ ТЕХНОЛОГИЙ ФЕДЕРАЛЬНОГО МЕДИКО-БИОЛОГИЧЕСКОГО АГЕНТСТВА"':'ФГБУ ФКЦ ВМТ ФМБА РОССИИ',
                   'ГАУЗ МО Клинская городская больница':'ГАУЗ МО КЛИНСКАЯ ГБ',
                   'ГБУЗ МО Бронницкая городская больница':'ГБУЗ МО Бронницкая '}

# %%
df2['Юридическое лицо']=df2['Юридическое лицо'].map(dict)

# %%
df2
# Out:
#                  Юридическое лицо     Фамилия         Имя        Отчество
# 0                             NaN      ЖУКОВА       МАРИЯ    ВЛАДИМИРОВНА
# 1     ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2  Афанасьева      Оксана      Дмитриевна
# 2     ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2  БЕЛЬДЕНКОВ  КОНСТАНТИН       СЕРГЕЕВИЧ
# 3     ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2     ВАВИЛОВ     ДМИТРИЙ     АНАТОЛЬЕВИЧ
# 4     ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2    ВАСИЛЬЕВ     НИКОЛАЙ      ВИКТОРОВИЧ
# ...                           ...         ...         ...             ...
# 6736     ФГБУ ФКЦ ВМТ ФМБА РОССИИ    ЩЕРБАКОВ   АЛЕКСАНДР       СЕРГЕЕВИЧ
# 6737     ФГБУ ФКЦ ВМТ ФМБА РОССИИ    ЯГОФАРОВ     ФАРАГАТ  МАННИАХМЕДОВИЧ
# 6738     ФГБУ ФКЦ ВМТ ФМБА РОССИИ   ЯГОФАРОВА     ГУЗАЛИЯ     ЗАКИУЛЛОВНА
# 6739     ФГБУ ФКЦ ВМТ ФМБА РОССИИ    КОРНЕЕВА   ВАЛЕНТИНА      НИКОЛАЕВНА
# 6740                          NaN     АГАРКОВ     НИКОЛАЙ      АЛЕКСЕЕВИЧ
#
# [6741 rows x 4 columns]

# %%
otch2 = df2.groupby(['Юридическое лицо'])['Имя'].count().reset_index()
otch2
# Out:
#                                      Юридическое лицо  Имя
# 0                         ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2   77
# 1                                 ГАУЗ МО КЛИНСКАЯ ГБ    1
# 2                                      ГАУЗ МО КЦВМиР  398
# 3                               ГАУЗ МО ХИМКИНСКАЯ ОБ  613
# 4                         ГАУЗ МО ЦГБ им. М.В. Гольца    8
# ..                                                ...  ...
# 58                              ГБУЗ МО ЩЕЛКОВСКАЯ ОБ    7
# 59                          ГБУЗ МО ЭЛЕКТРОГОРСКАЯ ГБ    3
# 60                       ГБУЗ МО ЭЛЕКТРОСТАЛЬСКАЯ ЦГБ  129
# 61  ФГБОУ ВО МГМСУ ИМ. А.И. ЕВДОКИМОВА МИНЗДРАВА Р...  647
# 62                           ФГБУ ФКЦ ВМТ ФМБА РОССИИ   67
#
# [63 rows x 2 columns]

# %%
df1
# Out:
#                       п/н                            ФИО      Пол  \
# 0                       1  ПЕРФИЛОВА ВАЛЕНТИНА СЕРГЕЕВНА  Женский
# 1                       2         ЦИКИНА НИНА АЛЕКСЕЕВНА  Женский
# 2                       3       КРАСОВСКИЙ ЮРИЙ ПАВЛОВИЧ  Мужской
# 3                       4    Стороженко Павел Аркадьевич  Мужской
# 4                       5      ХЛИВНАЯ ЕЛЕНА ГЕННАДЬЕВНА  Женский
# ...                   ...                            ...      ...
# 5504                 5505        ПАУКОВ НИКОЛАЙ ПАВЛОВИЧ  Мужской
# 5505                 5506     КОМКИНА ЗИНАИДА АНИСИМОВНА  Женский
# 5506                 5507      ТОКАР ЗИНАИДА АНАТОЛЬЕВНА  Женский
# 5507                 5508      Гуськов Владимир Иванович  Мужской
# 5508  Всего: 5508 записей                            NaN      NaN
#
#                            Медицинская организация  Дата исхода заболевания  \
# 0                                   ГБУЗ МО "ВРКБ"                      NaN
# ...

# %%
dict1={'ГАУЗ МО Воскресенская районная больница №2':'ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2',
                   'Больница НЦЧ РАН':'БПНЦ РАН',
                   'ГАУЗМО КЦВМиР':'ГАУЗ МО КЦВМиР',
                   'ГАУЗ МО "Химкинская ОБ"':'ГАУЗ МО ХИМКИНСКАЯ ОБ',
                   'ГАУЗ МО "ЦГБ им. М.В. Гольца"':'ГАУЗ МО ЦГБ им. М.В. Гольца',
                   'ГБУЗ МО "КЦРБ"':'ГБУЗ МО КАШИРСКАЯ ЦРБ',
                   'ГБУЗ МОСКОВСКОЙ ОБЛАСТИ  "ПОДОЛЬСКАЯ ГОРОДСКАЯ КЛИНИЧЕСКАЯ БОЛЬНИЦА"':'ГБУЗ МО ПОДОЛЬСКАЯ ГКБ',
                   'ГБУЗ МО "БАЛАШИХИНСКАЯ ОБЛАСТНАЯ БОЛЬНИЦА"':'ГБУЗ МО БАЛАШИХИНСКАЯ ОБ',
                   'ГАУЗ МО "ВРБ №2"':'ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2',
                   'ГБУЗ МО "ВОЛОКОЛАМСКАЯ ЦРБ"':'ГБУЗ МО ВОЛОКОЛАМСКАЯ ЦРБ',
                   'ГБУЗ МО "ВПРБ"':'ГБУЗ МО ВОСКРЕСЕНСКАЯ ПРБ',
                   'ГБУЗ МО "ГОЛИЦЫНСКАЯ ПОЛИКЛИНИКА"':'ГБУЗ МО ГОЛИЦЫНСКАЯ ПОЛИКЛИНИКА',
                   'ГБУЗ МО "ДАВЫДОВСКАЯ РАЙОННАЯ БОЛЬНИЦА"':'ГБУЗ МО ДАВЫДОВСКАЯ РБ',
                   'ГБУЗ МО Дедовская городская больница':'ГБУЗ МО ДЕДОВСКАЯ ГБ',
                   'ГБУЗ МО "ДЗЕРЖИНСКАЯ ГБ"':'ГБУЗ МО ДЗЕРЖИНСКАЯ ГБ',
                   'ГБУЗ МО "ДМИТРОВСКАЯ ОБЛАСТНАЯ БОЛЬНИЦА"':'ГБУЗ МО ДМИТРОВСКАЯ ОБ',
                   'ГБУЗ МО Долгопрудненская центральная городская больница':'ГБУЗ МО ДОЛГОПРУДНЕНСКАЯ ЦГБ',
                   'ГБУЗ МО "ДЦГБ"':'ГБУЗ МО ДОМОДЕДОВСКАЯ ЦГБ',
                   'ГБУЗ МО Щелковская областная больница':'ГБУЗ МО ЩЕЛКОВСКАЯ ОБ',
                   'ГБУЗ МО «Одинцовская ОБ»':'ГБУЗ МО ОДИНЦОВСКАЯ ОБ',
                   'ФГБОУ ВО МГМСУ им. А.И. Евдокимова Минздрава России':'ФГБОУ ВО МГМСУ ИМ. А.И. ЕВДОКИМОВА МИНЗДРАВА РОССИИ',
                   'ГБУЗ МО "ЭЦГБ"':'ГБУЗ МО ЭЛЕКТРОСТАЛЬСКАЯ ЦГБ',
                   'ФГБУ "3 центральный военный клинический госпиталь имени А.А. Вишневского"':'Филиал № 1ФГБУ «3 ЦВКГ им. А. А. Вишневского» Минобороны России',
                   'ГАУЗ МО Клинская городская больница':'ГАУЗ МО КЛИНСКАЯ ГБ',
                   'Филиал № 1ФГБУ «3 ЦВКГ им. А. А. Вишневского» Минобороны России':'Филиал № 1ФГБУ «3 ЦВКГ им. А. А. Вишневского» Минобороны России',
                   'ГБУЗ МО Бронницкая городская больница':'ГБУЗ МО БРОННИЦКАЯ ГБ'}

# %%
df1['Медицинская организация']=df1['Медицинская организация'].map(dict1)

# %%
df1
# Out:
#                       п/н                            ФИО      Пол  \
# 0                       1  ПЕРФИЛОВА ВАЛЕНТИНА СЕРГЕЕВНА  Женский
# 1                       2         ЦИКИНА НИНА АЛЕКСЕЕВНА  Женский
# 2                       3       КРАСОВСКИЙ ЮРИЙ ПАВЛОВИЧ  Мужской
# 3                       4    Стороженко Павел Аркадьевич  Мужской
# 4                       5      ХЛИВНАЯ ЕЛЕНА ГЕННАДЬЕВНА  Женский
# ...                   ...                            ...      ...
# 5504                 5505        ПАУКОВ НИКОЛАЙ ПАВЛОВИЧ  Мужской
# 5505                 5506     КОМКИНА ЗИНАИДА АНИСИМОВНА  Женский
# 5506                 5507      ТОКАР ЗИНАИДА АНАТОЛЬЕВНА  Женский
# 5507                 5508      Гуськов Владимир Иванович  Мужской
# 5508  Всего: 5508 записей                            NaN      NaN
#
#                   Медицинская организация  Дата исхода заболевания  \
# 0                  ГБУЗ МО ВИДНОВСКАЯ РКБ                      NaN
# ...

# %%
otch1 = df1.groupby(['Медицинская организация'])['ФИО'].count().reset_index()
otch1
# Out:
#                               Медицинская организация  ФИО
# 0                                            БПНЦ РАН    4
# 1                         ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2   78
# 2                                 ГАУЗ МО КЛИНСКАЯ ГБ    2
# 3                                      ГАУЗ МО КЦВМиР  409
# 4                               ГАУЗ МО ХИМКИНСКАЯ ОБ  573
# 5                         ГАУЗ МО ЦГБ им. М.В. Гольца    2
# 6                            ГБУЗ МО БАЛАШИХИНСКАЯ ОБ  172
# 7                              ГБУЗ МО ВИДНОВСКАЯ РКБ  431
# 8                           ГБУЗ МО ВОЛОКОЛАМСКАЯ ЦРБ   16
# 9                           ГБУЗ МО ВОСКРЕСЕНСКАЯ ПРБ    4
# 10                    ГБУЗ МО ГОЛИЦЫНСКАЯ ПОЛИКЛИНИКА    1
# 11                             ГБУЗ МО ДАВЫДОВСКАЯ РБ   56
# 12                             ГБУЗ МО ДЗЕРЖИНСКАЯ ГБ    1
# 13                             ГБУЗ МО ДМИТРОВСКАЯ ОБ   67
# 14                          ГБУЗ МО ДОМОДЕДОВСКАЯ ЦГБ   90
# ...

# %%
razn21=otch2.loc[~(otch2['Юридическое лицо'].isin(otch1['Медицинская организация'])),:] #есть в 2 но нет в 1
razn21
# Out:
#                                      Юридическое лицо  Имя
# 6                                 ГБУЗ МО Бронницкая     3
# 11                               ГБУЗ МО ДЕДОВСКАЯ ГБ    2
# 14                       ГБУЗ МО ДОЛГОПРУДНЕНСКАЯ ЦГБ   23
# 18                              ГБУЗ МО ЗАРАЙСКАЯ ЦРБ    1
# 21                           ГБУЗ МО КЛИМОВСКАЯ ГБ №2  109
# 22                             ГБУЗ МО КЛИМОВСКАЯ ДГБ    2
# 27                             ГБУЗ МО ЛИКИНИНСКАЯ ГБ    1
# 28                             ГБУЗ МО ЛОБНЕНСКАЯ ЦГБ   39
# 29                             ГБУЗ МО ЛУХОВЕЦКАЯ ЦГБ    9
# 36              ГБУЗ МО МОНИКИ ИМ. М.Ф. ВЛАДИМИРСКОГО   29
# 38                          ГБУЗ МО НАРО-ФОМИНСКАЯ ОБ  123
# 44                             ГБУЗ МО ПОДОЛЬСКАЯ ГКБ  192
# 45                             ГБУЗ МО ПОДОЛЬСКАЯ ДГБ   20
# 46                             ГБУЗ МО ПРОТВИНСКАЯ ГБ    6
# 48                              ГБУЗ МО РОШАЛЬСКАЯ ГБ    2
# ...

# %%
razn12=otch1.loc[~(otch1['Медицинская организация'].isin(otch2['Юридическое лицо'])),:]  #есть в 1 но нет в 2
razn12
# Out:
#                               Медицинская организация  ФИО
# 0                                            БПНЦ РАН    4
# 10                    ГБУЗ МО ГОЛИЦЫНСКАЯ ПОЛИКЛИНИКА    1
# 19                          ГБУЗ МО КЛИМОВСКАЯ ГБ № 2   27
# 24                            ГБУЗ МО ЛОТОШИНСКАЯ ЦРБ    1
# 45  Филиал № 1ФГБУ «3 ЦВКГ им. А. А. Вишневского» ...    1

# %%
otch2.rename(columns={'Юридическое лицо':'Медицинская организация'}, inplace=True)

# %%
razn = otch2.append(otch1).drop_duplicates(subset=['Медицинская организация'],keep=False) #разница 1 и 2
razn=razn.fillna(0)
cols=["Имя","ФИО",]
razn = razn.eval("разница={}".format("+".join(cols))).drop(columns=cols)
razn
# Out:
#                               Медицинская организация  разница
# 6                                 ГБУЗ МО Бронницкая       3.0
# 11                               ГБУЗ МО ДЕДОВСКАЯ ГБ      2.0
# 14                       ГБУЗ МО ДОЛГОПРУДНЕНСКАЯ ЦГБ     23.0
# 18                              ГБУЗ МО ЗАРАЙСКАЯ ЦРБ      1.0
# 21                           ГБУЗ МО КЛИМОВСКАЯ ГБ №2    109.0
# 22                             ГБУЗ МО КЛИМОВСКАЯ ДГБ      2.0
# 27                             ГБУЗ МО ЛИКИНИНСКАЯ ГБ      1.0
# 28                             ГБУЗ МО ЛОБНЕНСКАЯ ЦГБ     39.0
# 29                             ГБУЗ МО ЛУХОВЕЦКАЯ ЦГБ      9.0
# 36              ГБУЗ МО МОНИКИ ИМ. М.Ф. ВЛАДИМИРСКОГО     29.0
# 38                          ГБУЗ МО НАРО-ФОМИНСКАЯ ОБ    123.0
# 44                             ГБУЗ МО ПОДОЛЬСКАЯ ГКБ    192.0
# 45                             ГБУЗ МО ПОДОЛЬСКАЯ ДГБ     20.0
# 46                             ГБУЗ МО ПРОТВИНСКАЯ ГБ      6.0
# ...

# %%
sovp = otch2.merge(otch1, on="Медицинская организация")  #сумма совпадений
cols=["Имя","ФИО",]
sovp = sovp.eval("совпадения={}".format("+".join(cols))).drop(columns=cols)
sovp
# Out:
#                 Медицинская организация  совпадения
# 0           ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2         155
# 1                   ГАУЗ МО КЛИНСКАЯ ГБ           3
# 2                        ГАУЗ МО КЦВМиР         807
# 3                 ГАУЗ МО ХИМКИНСКАЯ ОБ        1186
# 4           ГАУЗ МО ЦГБ им. М.В. Гольца          10
# 5              ГБУЗ МО БАЛАШИХИНСКАЯ ОБ         386
# 6                ГБУЗ МО ВИДНОВСКАЯ РКБ         847
# 7             ГБУЗ МО ВОЛОКОЛАМСКАЯ ЦРБ          18
# 8             ГБУЗ МО ВОСКРЕСЕНСКАЯ ПРБ          14
# 9                ГБУЗ МО ДАВЫДОВСКАЯ РБ         108
# 10               ГБУЗ МО ДЗЕРЖИНСКАЯ ГБ          11
# 11               ГБУЗ МО ДМИТРОВСКАЯ ОБ         160
# 12            ГБУЗ МО ДОМОДЕДОВСКАЯ ЦГБ         197
# 13              ГБУЗ МО ЕГОРЬЕВСКАЯ ЦРБ         244
# 14                ГБУЗ МО ЖУКОВСКАЯ ГКБ         184
# 15             ГБУЗ МО ИВАНТЕЕВСКАЯ ЦГБ         155
# 16                ГБУЗ МО КАШИРСКАЯ ЦРБ         102
# ...

# %%
razn12.rename(columns={'ФИО':'разница_отч1_отч2'}, inplace=True)
razn21.rename(columns={'Имя':'разница_отч2_отч1'}, inplace=True)
razn21.rename(columns={'Юридическое лицо':'Медицинская организация'}, inplace=True)

res = otch2.merge(otch1,how='outer')
res = res.merge(razn12,how='outer')
res = res.merge(razn21,how='outer')
res = res.merge(razn,how='outer')
res = res.merge(sovp,how='outer')

res=res.fillna(0)

res.rename(columns={'Имя':'данные_отч1'}, inplace=True)
res.rename(columns={'ФИО':'данные_отч2'}, inplace=True)

res
# Out:
# C:\Users\1295864\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                               Медицинская организация  данные_отч1  \
# 0                         ГАУЗ МО ВОСКРЕСЕНСКАЯ РБ №2         77.0
# 1                                 ГАУЗ МО КЛИНСКАЯ ГБ          1.0
# 2                                      ГАУЗ МО КЦВМиР        398.0
# 3                               ГАУЗ МО ХИМКИНСКАЯ ОБ        613.0
# 4                         ГАУЗ МО ЦГБ им. М.В. Гольца          8.0
# ..                                                ...          ...
# 63                                           БПНЦ РАН          0.0
# 64                    ГБУЗ МО ГОЛИЦЫНСКАЯ ПОЛИКЛИНИКА          0.0
# ...

# %%
writer = pd.ExcelWriter('python_task.xlsx', engine='xlsxwriter')

# %%
res.to_excel(writer, sheet_name='Sheet1')
razn21.to_excel(writer, sheet_name='Sheet2')
razn12.to_excel(writer, sheet_name='Sheet3')
df1.to_excel(writer, sheet_name='Sheet4')
df2.to_excel(writer, sheet_name='Sheet5')

# %%
writer.save()
